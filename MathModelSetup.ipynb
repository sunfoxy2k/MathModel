# %%
os.chdir(PROJECT_PATH+"/"+GIT_REPOSITORY)

# %% [markdown]
# # conncent drive

# %%
from google.colab import drive
import os

# conncent phuc.phan1012000@hcmut.edu.vn

# default location for the drive
ROOT = "/content/drive"            
drive.mount(ROOT) 

MY_GOOGLE_DRIVE_PATH = 'My Drive/Work/Projects'
PROJECT_PATH = os.path.join(ROOT, MY_GOOGLE_DRIVE_PATH)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # connect Git

# %%
import pandas as pd

GIT_REPOSITORY = "MathModel"
# path to project on Google Drive
MY_GOOGLE_DRIVE_PATH = 'My Drive/Work/Projects'
PROJECT_PATH = os.path.join(ROOT, MY_GOOGLE_DRIVE_PATH)


# Clone github repository setup
GIT_USERNAME = 'phuc1012000'

# get token (ONLY phuc.phan1012000@hcmut.edu.vn have key access)
GIT_TOKEN = pd.read_pickle('/content/drive/My Drive/key.pkl')

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + \
    GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"

# %% [markdown]
# ## Git clone

# %%
os.chdir(PROJECT_PATH)
# clone the new github repository
# !git clone "{GIT_PATH}"
# Out:
# Cloning into 'MathModel'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %% [markdown]
# ## Git pull

# %%
os.chdir(os.path.join(PROJECT_PATH,GIT_REPOSITORY))

# pull repository
# !git pull origin master --force
# !git stash
# !git merge
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6 (delta 3), reused 6 (delta 3), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# From https://github.com/phuc1012000/kalapa-s-CreditScore
#  * branch            master     -> FETCH_HEAD
#    f70baa5..26ab55a  master     -> origin/master
# Updating f70baa5..26ab55a
# error: Your local changes to the following files would be overwritten by merge:
# 	src/Model/Naive_Model.ipynb
# Please commit your changes or stash them before you merge.
# Aborting

# %% [markdown]
# ## Git Push

# %%
# !git add .
# !git commit -m "Naive_Model"
# !git push origin mastergit
# Out:
# [master 2ab9538] Naive_Model
#  4 files changed, 40003 insertions(+), 999 deletions(-)
#  rewrite data_path.pkl (100%)
#  create mode 100644 outputs/naive_model.csv
#  create mode 100644 outputs/submission.csv
#  rewrite src/Model/Naive_Model.ipynb (99%)
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 201.75 KiB | 3.36 MiB/s, done.
# Total 8 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/phuc1012000/kalapa-s-CreditScore.git
#    26ab55a..2ab9538  master -> master

# %%
# get DataScience-Library repository from github
GIT_REPOSITORY = "DataScience-Library"
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + \
    GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
# rm exited file
# !rm - rf '/content/drive/My Drive/Work/Data_Science_Library/phuc'
# clone from git
os.chdir('/content/drive/My Drive/Work/Data_Science_Library')
# !git clone - b Developing "{GIT_PATH}"  # clone the github repository
# change name to phuc
# !mv '/content/drive/My Drive/Work/Data_Science_Library/DataScience-Library' \
    '/content/drive/My Drive/Work/Data_Science_Library/phuc'
